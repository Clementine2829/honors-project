# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import math

# %%
def kdd_train_pre_processing(df):
    
    """ partioning data into features and target """
    df[['Label']] = np.where(df[['Label']] == 'BENIGN', 1, 0)    
    
    X = df[['FlowDuration','TotalFwdPackets','TotalFwdPackets','TotalBackwardPackets',
            'TotalLengthofFwdPackets','TotalLengthofBwdPackets']]
    y = df[df.columns[-1]]
    
#    print("Pre processing x")
#    print(df)
#    print("Pre processing y")
#    print(y)
    
    return X, y

def kdd_test_pre_processing(df):

    """ partioning data into features and target """
    df.loc[df["protocol_type"] == "tcp", "protocol_type"] = 1
    df.loc[df["protocol_type"] == "udp", "protocol_type"] = 2
    df.loc[df["protocol_type"] == "icmp", "protocol_type"] = 3
    
    
    X = df[['duration','protocol_type','src_bytes','dst_bytes']]
    y = df.add("class", axis=1)
    
    return X, y

# %%
def train_data(x, y, test_size = 0.25, random_state = None):
    """ partioning the data into train and test sets """

    x_test = x.sample(frac=test_size, random_state=random_state)
    y_test = y[x_test.index]

    x_train = x.drop(x_test.index)
    y_train = y.drop(y_test.index)

    return x_train, x_test, y_train, y_test

def test_data(x, y, test_size = 0.25, random_state = None):
    """ partioning the data into train and test sets """

    x = x.sample(frac = test_size, random_state = random_state)
    
    return x, y

# %%
def exp_test(x):
    x.float()
    return np.exp(x)

def to_float_fun(x):
    for i in range(len(x)):
        #[i]= x[i].astype(np.float)
        for j in range(len(x[i])):
                x[i][j] = str(x[i][j]) + "."
                x[i][j] = round(float(x[i][j]), 0)
                #x[i][j] = math.floor(x[i][j])
                #x[i][j] = x[i][j].astype(np.float)

    return x

def to_float_cut(x):
    return math.floor(x)

# %%
def reshape_data(x):
    arr = []
    print(len(x))
    for i in range(x.size):
        temp_arr = []
        temp_arr.append(arr[i])
        arr.append(temp_arr)

    return arr

# %%
df_train = pd.read_csv("./data/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv")
df_test = pd.read_csv("./data/test_data.csv")


#print(df_train)
#print(df.columns)
#print(len(df.columns))

# remove special character
df_train.columns = df_train.columns.str.replace(' ', '')

# Split fearures and target
X_train, y_train = kdd_train_pre_processing(df_train)
#X_test, y_test = kdd_test_pre_processing(df_test)


# Split data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_data(X_train, y_train, test_size=.8, random_state=0)
#X_test, y_test = test_data(X_test, y_test, test_size=1, random_state=0)

# remove labels and convert to array
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

#.T -> change the matrix
#X_train, y_train, X_test, y_test = X_train.T, y_train.T, X_test.T, y_test.T
#y_train = y_train.reshape(1, -1)
#y_test = y_test.reshape(1, -1)

#print(X_train)
X_train = X_train.reshape(-1, 1, 6)
X_train = X_train.astype('float32')
X_train /= 255



X_test = X_test.reshape(-1, 1, 6)
X_test = X_test.astype('float32')
X_test /= 255



print(X_train)
print("\n")
print(y_train)
print("\n")
print(X_test)
print("\n")
print(y_test)
print("\n")
# Out:
# [[119945515       150       150         0         0         0]
#  [107015212        14        14        14       672       672]
#  [      302         2         2         2        68       190]
#  ...
#  [  1019181         9         9        11       703      3950]
#  [  3068031         5         5         1       117        41]
#  [ 44797921         6         6         5        36         0]]
# [[[4.7037456e+05 5.8823532e-01 5.8823532e-01 0.0000000e+00 0.0000000e+00
#    0.0000000e+00]]
#
#  [[4.1966750e+05 5.4901961e-02 5.4901961e-02 5.4901961e-02 2.6352942e+00
#    2.6352942e+00]]
#
#  [[1.1843138e+00 7.8431377e-03 7.8431377e-03 7.8431377e-03 2.6666668e-01
#    7.4509805e-01]]
#
#  ...
#
#  [[3.9967883e+03 3.5294119e-02 3.5294119e-02 4.3137256e-02 2.7568626e+00
#    1.5490196e+01]]
#
#  [[1.2031494e+04 1.9607844e-02 1.9607844e-02 3.9215689e-03 4.5882353e-01
#    1.6078432e-01]]
#
#  [[1.7567812e+05 2.3529412e-02 2.3529412e-02 1.9607844e-02 1.4117648e-01
#    0.0000000e+00]]]
#
#
# [1 1 1 ... 1 1 1]
#
#
# [[[4.6790947e+05 1.1372549e-01 1.1372549e-01 1.5686275e-01 5.5176473e+00
#    1.3984314e+02]]
#
#  [[4.6638372e+05 6.2745102e-02 6.2745102e-02 3.9215688e-02 4.6980391e+00
#    3.0368628e+01]]
#
#  [[9.3227448e+01 3.9215689e-03 3.9215689e-03 3.9215689e-03 0.0000000e+00
#    0.0000000e+00]]
#
#  ...
#
#  [[4.4589804e+02 7.8431377e-03 7.8431377e-03 7.8431377e-03 2.4313726e-01
#    1.4823530e+00]]
#
#  [[1.3764706e+00 7.8431377e-03 7.8431377e-03 0.0000000e+00 4.7058824e-02
#    0.0000000e+00]]
#
#  [[1.8951373e+02 7.8431377e-03 7.8431377e-03 7.8431377e-03 2.3529412e-01
#    7.3725492e-01]]]
#
#
# [1 1 1 ... 1 1 1]
